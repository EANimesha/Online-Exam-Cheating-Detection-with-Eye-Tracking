# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df =  pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Research/Test Data/webquiz_good.csv',names=["X", "Y"])

# %%
df.shape
# Out:
# (1261, 2)

# %%
df =  pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Research/Test Data/Madushanka/gazeData.csv',names=["X", "Y"])
#68, 1323,533, 39
df=df[:-9]

# %%
df.head()
# Out:
#          X      Y
# 0  1047.02  53.51
# 1  1083.12  52.96
# 2  1090.55  47.18
# 3  1106.09  65.03
# 4  1116.80  65.15

# %%
df=df[:-100]

# %% [markdown]
# # Displaying the gaze points and screen boundaries/edges - Scatter PLot

# %%
# x1=-21
# x2=1332
# y1=822
# y2=23

x1,x2,y1,y2=68, 1323, 39,533

# %%
df.plot(kind='scatter', x='X', y='Y')
plt.ylim(1000,-200)
plt.axvline(x=-26,color='red')
plt.axvline(x=1332,color='red')
plt.axhline(y=822,color='green')
plt.axhline(y=23,color='green')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# In the above graph I have plotted the lines of boundaries in red and green color. red lines - > x min and x max of screen, green line -> y min and y max of screen

# %% [markdown]
# # Display Data Using Seaboarn KDE - Kernal Density Image

# %%
m=2129

df =  pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Research/Final Solution/raw/visualize - non cheat.csv',names=["t","X", "Y"])
l= df[m+1:m+5]['t'].values.tolist()
# df=df[:1300]

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.image as mpimg 

# file = "/content/drive/MyDrive/Colab Notebooks/Research/gazeData7.csv"
# df = pd.read_csv(file)
import seaborn as sns
map_img = mpimg.imread('/content/drive/MyDrive/Colab Notebooks/Research/Final Solution/raw/img.jpeg')

# %%
l
# Out:
# [47.0, 1505.0, 857.0, 56.0]

# %%
x= df['X'].to_numpy()
y= df['Y'].to_numpy()

sns.set(rc={'figure.figsize':(14.9,7.69)})
# hmax = sns.kdeplot(x, y, cmap="Blues", shade=True, bw=.25, alpha=0.7, zorder=2)
hmax = sns.kdeplot(x, y, cmap="Blues", shade=True, bw=.10, alpha=0.8, zorder=2,levels=25)
# hmax.collections[0].set_alpha(0.5)

plt.imshow(map_img, zorder=1, extent=[l[0],l[1],l[2],l[3]])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
hmax = sns.scatterplot(x, y)
plt.axvline(x=l[0],color='red')
plt.axvline(x=l[1],color='red')
plt.axhline(y=l[2],color='green')
plt.axhline(y=l[3],color='green')
plt.imshow(map_img, zorder=0, extent=[l[0],l[1],l[2],l[3]])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Cheating Case

# %%
df =  pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Research/Test Data/webquiz_cheat.csv',names=["X", "Y"])

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.image as mpimg 

import seaborn as sns
map_img = mpimg.imread('/content/drive/MyDrive/Colab Notebooks/Research/Test Data/webq.png') 

x= df['X'].to_numpy()
y= df['Y'].to_numpy()

# %%
sns.set(rc={'figure.figsize':(15.36,8.32)})
hmax = sns.kdeplot(x, y, cmap="Blues", shade=True, bw=.10, alpha=0.8, zorder=2,levels=20)
# hmax.collections[0].set_alpha(0.5)
plt.ylim(1200,-400)
plt.xlim(-1200,1800)
plt.imshow(map_img, zorder=1, extent=[60.0, 1537.0, 856.0, 72.0])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot(x, y,zorder=2,)
plt.ylim(1200,-400)
plt.xlim(-1200,1800)
# plt.axvline(x=60,color='red')
# plt.axvline(x=1537,color='red')
# plt.axhline(y=856,color='green')
# plt.axhline(y=72,color='green')
plt.imshow(map_img, zorder=1, extent=[60.0, 1537.0, 856.0, 72.0])


plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Normal Case

# %%
df =  pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Research/Test Data/webquiz_normal.csv',names=["X", "Y"])

# %%
df=df[:-100]

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.image as mpimg 

import seaborn as sns
map_img = mpimg.imread('/content/drive/MyDrive/Colab Notebooks/Research/Test Data/webq.png') 

x= df['X'].to_numpy()
y= df['Y'].to_numpy()

# %%
sns.scatterplot(x, y,zorder=2,)
plt.ylim(1200,-400)
plt.xlim(-1200,1800)
plt.axvline(x=49,color='red')
plt.axvline(x=1399,color='red')
plt.axhline(y=817,color='green')
plt.axhline(y=65,color='green')
# plt.imshow(map_img, zorder=1, extent=[60.0, 1537.0, 856.0, 72.0])


plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.set(rc={'figure.figsize':(15.36,8.32)})
hmax = sns.kdeplot(x, y, cmap="Blues", shade=True, bw=.25, alpha=0.7, zorder=2)
# hmax.collections[0].set_alpha(0.5)

plt.imshow(map_img, zorder=1, extent=[60.0, 1537.0, 856.0, 72.0])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
